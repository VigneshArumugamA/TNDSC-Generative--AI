# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

#import numpy as np # linear algebra
#import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

#import os
#for dirname, _, filenames in os.walk('/kaggle/input'):
   # for filename in filenames:
      #  print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import os
import time
import random
import numpy as np
import pandas as pd
import cv2, torch
from tqdm.auto import tqdm
import shutil as sh

from IPython.display import Image, clear_output
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# !pip install -U pycocotools
# !pip install -qr yolov5/requirements.txt  # install dependencies
# !cp yolov5/requirements.txt ./
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16517, done.
# remote: Counting objects: 100% (115/115), done.
# remote: Compressing objects: 100% (99/99), done.
# remote: Total 16517 (delta 47), reused 50 (delta 16), pack-reused 16402
# Receiving objects: 100% (16517/16517), 15.17 MiB | 31.25 MiB/s, done.
# Resolving deltas: 100% (11304/11304), done.
# Collecting pycocotools
#   Downloading pycocotools-2.0.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: matplotlib>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from pycocotools) (3.7.5)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from pycocotools) (1.26.4)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools) (1.16.0)
# Downloading pycocotools-2.0.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (426 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 426.2/426.2 kB 8.6 MB/s eta 0:00:00
# Installing collected packages: pycocotools
# Successfully installed pycocotools-2.0.7

# %%
img_h, img_w, num_channels = (380, 676, 3) 
df = pd.read_csv('../input/car-object-detection/data/train_solution_bounding_boxes (1).csv')
df.rename(columns={'image':'image_id'}, inplace=True) #rename the imgae column as the convention in yolo5
df['image_id'] = df['image_id'].apply(lambda x: x.split('.')[0])
# remove the file extension from the image id column
df['x_center'] = (df['xmin'] + df['xmax'])/2 # center coordinate calclations
df['y_center'] = (df['ymin'] + df['ymax'])/2
df['w'] = df['xmax'] - df['xmin'] # wifht and height calculation
df['h'] = df['ymax'] - df['ymin']
df['classes'] = 0
df['x_center'] = df['x_center']/img_w   # Normalization of coordinates they should be between 0 and 1
df['w'] = df['w']/img_w
df['y_center'] = df['y_center']/img_h
df['h'] = df['h']/img_h
df.head()
# Out:
#       image_id        xmin        ymin        xmax        ymax  x_center  \
# 0   vid_4_1000  281.259045  187.035071  327.727931  223.225547  0.450434
# 1  vid_4_10000   15.163531  187.035071  120.329957  236.430180  0.100217
# 2  vid_4_10040  239.192475  176.764801  361.968162  236.430180  0.444645
# 3  vid_4_10020  496.483358  172.363256  630.020260  231.539575  0.833213
# 4  vid_4_10060   16.630970  186.546010  132.558611  238.386422  0.110347
#
#    y_center         w         h  classes
# 0  0.539817  0.068741  0.095238        0
# 1  0.557191  0.155572  0.129987        0
# 2  0.543678  0.181621  0.157014        0
# 3  0.531451  0.197540  0.155727        0
# 4  0.559122  0.171491  0.136422        0

# %% [markdown]
# lets display a random imgae

# %%
index = list(set(df.image_id))
image = random.choice(index)
print("Image ID: %s"%(image))
img = cv2.imread(f'/kaggle/input/car-object-detection/data/training_images/{image}.jpg')
img.shape
# Out:
# Image ID: vid_4_21500
# (380, 676, 3)

# %%
image = random.choice(index)
Image(filename=f'/kaggle/input/car-object-detection/data/training_images/{image}.jpg',width=600)

# %%
source = 'training_images'
if True:
    for fold in [0]:
        val_index = index[len(index)*fold//5:len(index)*(fold+1)//5]
        for name,mini in tqdm(df.groupby('image_id')):
            if name in val_index:
                path2save = 'val2017/'
            else:
                path2save = 'train2017/'
            if not os.path.exists('/tmp/convertor/fold{}/labels/'.format(fold)+path2save):
                os.makedirs('/tmp/convertor/fold{}/labels/'.format(fold)+path2save)
            with open('/tmp/convertor/fold{}/labels/'.format(fold)+path2save+name+".txt", 'w+') as f:
                row = mini[['classes','x_center','y_center','w','h']].astype(float).values
                row = row.astype(str)
                for j in range(len(row)):
                    text = ' '.join(row[j])
                    f.write(text)
                    f.write("\n")
            if not os.path.exists('/tmp/convertor/fold{}/images/{}'.format(fold,path2save)):
                os.makedirs('/tmp/convertor/fold{}/images/{}'.format(fold,path2save))
            sh.copy("/kaggle/input/car-object-detection/data/{}/{}.jpg".format(source,name),'/tmp/convertor/fold{}/images/{}/{}.jpg'.format(fold,path2save,name))
# Out:
#   0%|          | 0/355 [00:00<?, ?it/s]

# %%
# !python yolov5/detect.py --weights yolov5/yolov5s.pt --img 676 --conf 0.4 --source /kaggle/input/car-object-detection/data/testing_images
# this part of the code determines the directories for the yolofile the weights to be loaded,
# setting the input imgae sizes, and confidence score setup
# Out:
# detect: weights=['yolov5/yolov5s.pt'], source=/kaggle/input/car-object-detection/data/testing_images, data=yolov5/data/coco128.yaml, imgsz=[676, 676], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-294-gdb125a20 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt to yolov5/yolov5s.pt...
# 100%|███████████████████████████████████████| 14.1M/14.1M [00:00<00:00, 192MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# WARNING ⚠️ --img-size [676, 676] must be multiple of max stride 32, updating to [704, 704]
# image 1/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_25100.jpg: 416x704 (no detections), 41.6ms
# image 2/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_25120.jpg: 416x704 (no detections), 6.1ms
# image 3/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_25140.jpg: 416x704 (no detections), 6.2ms
# image 4/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_25160.jpg: 416x704 (no detections), 6.1ms
# image 5/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_25180.jpg: 416x704 (no detections), 5.9ms
# image 6/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_25200.jpg: 416x704 (no detections), 5.9ms
# image 7/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_25220.jpg: 416x704 (no detections), 6.5ms
# image 8/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_25240.jpg: 416x704 (no detections), 6.0ms
# image 9/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_25260.jpg: 416x704 (no detections), 5.9ms
# image 10/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_26320.jpg: 416x704 (no detections), 6.0ms
# image 11/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_26400.jpg: 416x704 (no detections), 5.9ms
# image 12/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_26420.jpg: 416x704 (no detections), 5.9ms
# image 13/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_26560.jpg: 416x704 1 car, 5.9ms
# image 14/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_26580.jpg: 416x704 1 car, 6.3ms
# image 15/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_26600.jpg: 416x704 2 cars, 6.1ms
# image 16/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_26620.jpg: 416x704 1 car, 5.8ms
# image 17/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_26640.jpg: 416x704 3 cars, 5.8ms
# image 18/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_26660.jpg: 416x704 1 car, 6.0ms
# image 19/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_26680.jpg: 416x704 3 cars, 1 truck, 5.8ms
# image 20/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_26700.jpg: 416x704 2 cars, 6.6ms
# image 21/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_26720.jpg: 416x704 3 cars, 6.0ms
# image 22/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_26740.jpg: 416x704 3 cars, 6.8ms
# image 23/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_26760.jpg: 416x704 3 cars, 5.8ms
# image 24/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_26780.jpg: 416x704 2 cars, 1 truck, 6.9ms
# image 25/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_26800.jpg: 416x704 2 cars, 1 truck, 5.8ms
# image 26/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_26820.jpg: 416x704 2 cars, 8.5ms
# image 27/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_26840.jpg: 416x704 1 car, 5.9ms
# image 28/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_26860.jpg: 416x704 1 car, 6.2ms
# image 29/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_26880.jpg: 416x704 1 car, 6.0ms
# image 30/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_26900.jpg: 416x704 3 cars, 5.9ms
# image 31/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_26920.jpg: 416x704 2 cars, 5.9ms
# image 32/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_26940.jpg: 416x704 2 cars, 6.3ms
# image 33/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_26960.jpg: 416x704 1 car, 5.8ms
# image 34/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_26980.jpg: 416x704 (no detections), 6.0ms
# image 35/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_27240.jpg: 416x704 1 car, 6.0ms
# image 36/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_27260.jpg: 416x704 (no detections), 5.9ms
# image 37/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_27280.jpg: 416x704 (no detections), 6.3ms
# image 38/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_27300.jpg: 416x704 3 cars, 3 traffic lights, 6.4ms
# image 39/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_27320.jpg: 416x704 3 cars, 4 traffic lights, 6.0ms
# image 40/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_27360.jpg: 416x704 3 cars, 5 traffic lights, 6.0ms
# image 41/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_27380.jpg: 416x704 3 cars, 5 traffic lights, 5.9ms
# image 42/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_27400.jpg: 416x704 3 cars, 4 traffic lights, 6.0ms
# image 43/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_27420.jpg: 416x704 3 cars, 3 traffic lights, 6.2ms
# image 44/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_27440.jpg: 416x704 3 cars, 2 traffic lights, 6.4ms
# image 45/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_27460.jpg: 416x704 2 cars, 2 traffic lights, 6.2ms
# image 46/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_27480.jpg: 416x704 4 cars, 1 traffic light, 6.2ms
# image 47/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_27500.jpg: 416x704 1 car, 6.1ms
# image 48/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_27520.jpg: 416x704 2 cars, 6.2ms
# image 49/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_27540.jpg: 416x704 2 cars, 6.1ms
# image 50/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_27560.jpg: 416x704 1 car, 6.6ms
# image 51/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_27580.jpg: 416x704 (no detections), 6.2ms
# image 52/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_27600.jpg: 416x704 (no detections), 6.1ms
# image 53/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_27620.jpg: 416x704 1 car, 6.2ms
# image 54/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_27640.jpg: 416x704 1 car, 6.2ms
# image 55/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_27660.jpg: 416x704 (no detections), 5.8ms
# image 56/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_27680.jpg: 416x704 (no detections), 6.1ms
# image 57/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_27700.jpg: 416x704 (no detections), 5.9ms
# image 58/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_27720.jpg: 416x704 (no detections), 6.1ms
# image 59/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_27740.jpg: 416x704 (no detections), 5.7ms
# image 60/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_27760.jpg: 416x704 (no detections), 5.8ms
# image 61/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_27780.jpg: 416x704 (no detections), 5.9ms
# image 62/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_27800.jpg: 416x704 (no detections), 6.0ms
# image 63/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_27820.jpg: 416x704 (no detections), 5.8ms
# image 64/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_27840.jpg: 416x704 1 car, 5.7ms
# image 65/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_27860.jpg: 416x704 1 car, 6.0ms
# image 66/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_27880.jpg: 416x704 1 car, 5.8ms
# image 67/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_27900.jpg: 416x704 1 car, 6.0ms
# image 68/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_27920.jpg: 416x704 1 car, 5.9ms
# image 69/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_27940.jpg: 416x704 1 truck, 5.9ms
# image 70/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_27960.jpg: 416x704 (no detections), 5.9ms
# image 71/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_27980.jpg: 416x704 1 chair, 5.8ms
# image 72/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_28000.jpg: 416x704 (no detections), 5.7ms
# image 73/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_28020.jpg: 416x704 (no detections), 5.8ms
# image 74/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_28040.jpg: 416x704 (no detections), 5.9ms
# image 75/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_28060.jpg: 416x704 (no detections), 6.0ms
# image 76/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_28080.jpg: 416x704 (no detections), 6.1ms
# image 77/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_28180.jpg: 416x704 (no detections), 5.8ms
# image 78/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_28260.jpg: 416x704 1 car, 6.2ms
# image 79/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_28320.jpg: 416x704 (no detections), 6.0ms
# image 80/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_28340.jpg: 416x704 (no detections), 6.1ms
# image 81/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_28360.jpg: 416x704 (no detections), 7.2ms
# image 82/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_28380.jpg: 416x704 1 car, 6.0ms
# image 83/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_28420.jpg: 416x704 1 car, 6.6ms
# image 84/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_28440.jpg: 416x704 1 car, 1 truck, 5.9ms
# image 85/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_28460.jpg: 416x704 (no detections), 7.0ms
# image 86/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_28480.jpg: 416x704 (no detections), 6.1ms
# image 87/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_28500.jpg: 416x704 1 car, 6.6ms
# image 88/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_28520.jpg: 416x704 1 car, 1 truck, 6.0ms
# image 89/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_28540.jpg: 416x704 1 truck, 6.6ms
# image 90/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_28560.jpg: 416x704 (no detections), 5.9ms
# image 91/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_28580.jpg: 416x704 (no detections), 5.9ms
# image 92/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_28600.jpg: 416x704 (no detections), 5.9ms
# image 93/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_28620.jpg: 416x704 (no detections), 5.8ms
# image 94/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_28640.jpg: 416x704 (no detections), 5.8ms
# image 95/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_28660.jpg: 416x704 (no detections), 6.1ms
# image 96/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_28680.jpg: 416x704 (no detections), 6.0ms
# image 97/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_28700.jpg: 416x704 (no detections), 5.9ms
# image 98/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_29000.jpg: 416x704 2 cars, 5.9ms
# image 99/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_29020.jpg: 416x704 1 car, 5.9ms
# image 100/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_29040.jpg: 416x704 1 car, 6.0ms
# image 101/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_29060.jpg: 416x704 (no detections), 6.0ms
# image 102/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_29080.jpg: 416x704 (no detections), 6.1ms
# image 103/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_29100.jpg: 416x704 (no detections), 6.1ms
# image 104/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_29400.jpg: 416x704 1 car, 6.8ms
# image 105/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_29420.jpg: 416x704 2 cars, 6.0ms
# image 106/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_29440.jpg: 416x704 2 cars, 6.1ms
# image 107/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_29460.jpg: 416x704 1 car, 6.8ms
# image 108/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_29480.jpg: 416x704 1 car, 6.3ms
# image 109/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_29500.jpg: 416x704 (no detections), 6.4ms
# image 110/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_29520.jpg: 416x704 (no detections), 6.5ms
# image 111/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_29540.jpg: 416x704 2 cars, 6.2ms
# image 112/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_29560.jpg: 416x704 1 car, 6.3ms
# image 113/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_29580.jpg: 416x704 1 car, 6.3ms
# image 114/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_29600.jpg: 416x704 (no detections), 5.9ms
# image 115/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_29620.jpg: 416x704 (no detections), 6.2ms
# image 116/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_29640.jpg: 416x704 (no detections), 6.1ms
# image 117/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_29720.jpg: 416x704 (no detections), 6.1ms
# image 118/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_29740.jpg: 416x704 (no detections), 5.9ms
# image 119/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_29760.jpg: 416x704 1 car, 6.1ms
# image 120/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_29820.jpg: 416x704 1 car, 6.2ms
# image 121/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_29840.jpg: 416x704 1 car, 1 truck, 6.2ms
# image 122/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_29860.jpg: 416x704 (no detections), 6.2ms
# image 123/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_29880.jpg: 416x704 (no detections), 5.9ms
# image 124/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_29900.jpg: 416x704 (no detections), 6.0ms
# image 125/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_29980.jpg: 416x704 1 person, 6.1ms
# image 126/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_30000.jpg: 416x704 (no detections), 6.1ms
# image 127/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_30020.jpg: 416x704 (no detections), 6.2ms
# image 128/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_30040.jpg: 416x704 (no detections), 5.9ms
# image 129/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_30120.jpg: 416x704 (no detections), 6.1ms
# image 130/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_30140.jpg: 416x704 (no detections), 5.9ms
# image 131/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_30160.jpg: 416x704 (no detections), 5.8ms
# image 132/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_30180.jpg: 416x704 (no detections), 5.9ms
# image 133/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_30640.jpg: 416x704 1 car, 5.8ms
# image 134/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_30660.jpg: 416x704 (no detections), 5.8ms
# image 135/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_30680.jpg: 416x704 (no detections), 5.7ms
# image 136/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_30700.jpg: 416x704 (no detections), 6.4ms
# image 137/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_30720.jpg: 416x704 (no detections), 6.1ms
# image 138/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_30740.jpg: 416x704 1 car, 1 truck, 5.9ms
# image 139/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_30760.jpg: 416x704 1 car, 3 traffic lights, 6.1ms
# image 140/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_30820.jpg: 416x704 2 cars, 6 traffic lights, 6.0ms
# image 141/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_30840.jpg: 416x704 2 cars, 5 traffic lights, 6.0ms
# image 142/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_30860.jpg: 416x704 3 cars, 3 traffic lights, 6.3ms
# image 143/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_30920.jpg: 416x704 2 cars, 2 traffic lights, 7.0ms
# image 144/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_30940.jpg: 416x704 2 cars, 2 traffic lights, 6.3ms
# image 145/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_31020.jpg: 416x704 2 cars, 6.3ms
# image 146/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_31040.jpg: 416x704 3 cars, 5.8ms
# image 147/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_31060.jpg: 416x704 1 car, 6.9ms
# image 148/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_31080.jpg: 416x704 2 cars, 5.9ms
# image 149/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_31100.jpg: 416x704 1 car, 7.1ms
# image 150/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_31120.jpg: 416x704 2 cars, 5.7ms
# image 151/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_31140.jpg: 416x704 1 car, 6.9ms
# image 152/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_31160.jpg: 416x704 1 car, 5.7ms
# image 153/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_31180.jpg: 416x704 (no detections), 6.2ms
# image 154/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_31200.jpg: 416x704 (no detections), 6.2ms
# image 155/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_31260.jpg: 416x704 (no detections), 6.9ms
# image 156/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_31280.jpg: 416x704 (no detections), 5.8ms
# image 157/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_31300.jpg: 416x704 (no detections), 6.0ms
# image 158/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_31360.jpg: 416x704 (no detections), 5.8ms
# image 159/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_31380.jpg: 416x704 (no detections), 5.8ms
# image 160/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_31400.jpg: 416x704 (no detections), 5.9ms
# image 161/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_31420.jpg: 416x704 (no detections), 6.0ms
# image 162/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_31480.jpg: 416x704 (no detections), 5.9ms
# image 163/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_31500.jpg: 416x704 (no detections), 5.8ms
# image 164/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_31520.jpg: 416x704 (no detections), 6.7ms
# image 165/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_31560.jpg: 416x704 1 car, 5.9ms
# image 166/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_31600.jpg: 416x704 2 cars, 6.7ms
# image 167/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_31620.jpg: 416x704 1 car, 6.0ms
# image 168/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_31640.jpg: 416x704 (no detections), 6.9ms
# image 169/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_31660.jpg: 416x704 (no detections), 6.0ms
# image 170/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_31680.jpg: 416x704 (no detections), 6.9ms
# image 171/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_31700.jpg: 416x704 1 car, 5.9ms
# image 172/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_31720.jpg: 416x704 1 car, 7.0ms
# image 173/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_400.jpg: 416x704 1 car, 6.1ms
# image 174/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_420.jpg: 416x704 1 car, 7.2ms
# image 175/175 /kaggle/input/car-object-detection/data/testing_images/vid_5_440.jpg: 416x704 1 car, 8.7ms
# Speed: 0.4ms pre-process, 6.4ms inference, 3.1ms NMS per image at shape (1, 3, 704, 704)
# Results saved to yolov5/runs/detect/exp

# %%
predicted_files = []
for (dirpath, dirnames, filenames) in os.walk("runs/detect/py"):
    predicted_files.extend(filenames)

# %%
Image(filename='/kaggle/working/yolov5/runs/detect/exp/vid_5_29400.jpg')

# %%
Image(filename='/kaggle/working/yolov5/runs/detect/exp/vid_5_29580.jpg')

# %%
Image(filename='/kaggle/working/yolov5/runs/detect/exp/vid_5_30720.jpg')

# %%
Image(filename='/kaggle/working/yolov5/runs/detect/exp/vid_5_28540.jpg')

# %%
Image(filename='/kaggle/working/yolov5/runs/detect/exp/vid_5_26740.jpg')
